# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import pycountry

# %%
iea_df = pd.read_csv('iea_clean.csv')
iea_df
# Out:
#       Unnamed: 0     region        category       parameter    mode  \
# 0              0  Australia      Historical        EV stock    Cars
# 1              1  Australia      Historical  EV sales share    Cars
# 2              2  Australia      Historical  EV stock share    Cars
# 3              3  Australia      Historical        EV sales    Cars
# 4              4  Australia      Historical        EV sales    Cars
# ...          ...        ...             ...             ...     ...
# 9537        9537      World  Projection-APS        EV stock  Trucks
# 9538        9538      World  Projection-APS        EV stock    Vans
# 9539        9539      World  Projection-APS        EV stock    Vans
# 9540        9540      World  Projection-APS        EV stock    Cars
# 9541        9541      World  Projection-APS        EV stock    Cars
#
#      powertrain  year      unit         value
# 0           BEV  2011  Vehicles  4.900000e+01
# 1            EV  2011   percent  6.500000e-03
# 2            EV  2011   percent  4.600000e-04
# 3           BEV  2011  Vehicles  4.900000e+01
# 4           BEV  2012  Vehicles  1.700000e+02
# ...         ...   ...       ...           ...
# 9537       PHEV  2030  Vehicles  9.100000e+05
# 9538        BEV  2030  Vehicles  1.200000e+07
# 9539       PHEV  2030  Vehicles  1.300000e+06
# 9540        BEV  2030  Vehicles  1.800000e+08
# 9541       PHEV  2030  Vehicles  5.000000e+07
#
# [9542 rows x 9 columns]

# %%
iea_df = iea_df.drop(columns='Unnamed: 0', axis=1)
iea_df
# Out:
#          region        category       parameter    mode powertrain  year  \
# 0     Australia      Historical        EV stock    Cars        BEV  2011
# 1     Australia      Historical  EV sales share    Cars         EV  2011
# 2     Australia      Historical  EV stock share    Cars         EV  2011
# 3     Australia      Historical        EV sales    Cars        BEV  2011
# 4     Australia      Historical        EV sales    Cars        BEV  2012
# ...         ...             ...             ...     ...        ...   ...
# 9537      World  Projection-APS        EV stock  Trucks       PHEV  2030
# 9538      World  Projection-APS        EV stock    Vans        BEV  2030
# 9539      World  Projection-APS        EV stock    Vans       PHEV  2030
# 9540      World  Projection-APS        EV stock    Cars        BEV  2030
# 9541      World  Projection-APS        EV stock    Cars       PHEV  2030
#
#           unit         value
# 0     Vehicles  4.900000e+01
# 1      percent  6.500000e-03
# 2      percent  4.600000e-04
# 3     Vehicles  4.900000e+01
# 4     Vehicles  1.700000e+02
# ...        ...           ...
# 9537  Vehicles  9.100000e+05
# 9538  Vehicles  1.200000e+07
# 9539  Vehicles  1.300000e+06
# 9540  Vehicles  1.800000e+08
# 9541  Vehicles  5.000000e+07
#
# [9542 rows x 8 columns]

# %%
iea_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9542 entries, 0 to 9541
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      9542 non-null   object
#  1   category    9542 non-null   object
#  2   parameter   9542 non-null   object
#  3   mode        9542 non-null   object
#  4   powertrain  9542 non-null   object
#  5   year        9542 non-null   int64
#  6   unit        9542 non-null   object
#  7   value       9542 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 596.5+ KB

# %%
print(iea_df.isna().sum())
# Out:
# region        0
# category      0
# parameter     0
# mode          0
# powertrain    0
# year          0
# unit          0
# value         0
# dtype: int64

# %%
def convert_alpha3(df=pd.DataFrame):
    alpha3 = []
    others = []

    for land in df["region"]:
        try:
            alpha3.append(pycountry.countries.get(name=land).alpha_3)
        except:
            others.append(land)

    # print(set(alpha3))
    # print(set(others))
    
    return alpha3, others

# %%
alpha3, others = convert_alpha3(iea_df)

print(set(alpha3))
print(set(others))
# Out:
# {'DEU', 'IND', 'ISR', 'CHE', 'AUT', 'AUS', 'CHN', 'NLD', 'BRA', 'POL', 'ZAF', 'SWE', 'BEL', 'GRC', 'NZL', 'ITA', 'CHL', 'GBR', 'DNK', 'IDN', 'CAN', 'MEX', 'FIN', 'ISL', 'NOR', 'ESP', 'THA', 'FRA', 'JPN', 'PRT'}
# {'USA', 'EU27', 'Turkiye', 'Korea', 'Rest of the world', 'World', 'Other Europe', 'Europe'}

# %%
iea_clean_df = iea_df.copy()
andere = []

for land in iea_clean_df["region"]:
    if land == "USA":
        iea_clean_df.replace(to_replace=land, value="United States of America", inplace=True)
    elif land == "Turkiye":
        iea_clean_df.replace(to_replace=land, value="Turkey", inplace=True)
    elif land == "Korea":
        iea_clean_df.replace(to_replace=land, value='Republic of Korea', inplace=True)
    else:
        andere.append('land')

# %%
alpha3_clean, others_clean = convert_alpha3(iea_clean_df)

print(set(alpha3_clean))
print(set(others_clean))
# Out:
# {'DEU', 'TUR', 'IND', 'ISR', 'CHE', 'AUT', 'AUS', 'CHN', 'NLD', 'BRA', 'POL', 'ZAF', 'SWE', 'BEL', 'GRC', 'NZL', 'ITA', 'CHL', 'GBR', 'DNK', 'IDN', 'CAN', 'MEX', 'FIN', 'ISL', 'NOR', 'ESP', 'THA', 'FRA', 'JPN', 'PRT'}
# {'EU27', 'Republic of Korea', 'Rest of the world', 'United States of America', 'World', 'Other Europe', 'Europe'}

# %%
iea_clean_df.insert(loc=0, column='alpha3_code', value='no code')

# %%
iea_clean_df
# Out:
#      alpha3_code     region        category       parameter    mode  \
# 0        no code  Australia      Historical        EV stock    Cars
# 1        no code  Australia      Historical  EV sales share    Cars
# 2        no code  Australia      Historical  EV stock share    Cars
# 3        no code  Australia      Historical        EV sales    Cars
# 4        no code  Australia      Historical        EV sales    Cars
# ...          ...        ...             ...             ...     ...
# 9537     no code      World  Projection-APS        EV stock  Trucks
# 9538     no code      World  Projection-APS        EV stock    Vans
# 9539     no code      World  Projection-APS        EV stock    Vans
# 9540     no code      World  Projection-APS        EV stock    Cars
# 9541     no code      World  Projection-APS        EV stock    Cars
#
#      powertrain  year      unit         value
# 0           BEV  2011  Vehicles  4.900000e+01
# 1            EV  2011   percent  6.500000e-03
# 2            EV  2011   percent  4.600000e-04
# 3           BEV  2011  Vehicles  4.900000e+01
# 4           BEV  2012  Vehicles  1.700000e+02
# ...         ...   ...       ...           ...
# 9537       PHEV  2030  Vehicles  9.100000e+05
# 9538        BEV  2030  Vehicles  1.200000e+07
# 9539       PHEV  2030  Vehicles  1.300000e+06
# 9540        BEV  2030  Vehicles  1.800000e+08
# 9541       PHEV  2030  Vehicles  5.000000e+07
#
# [9542 rows x 9 columns]

# %%
i = 0
for regi in iea_clean_df['region']:
    if regi == 'United States of America':
        iea_clean_df.at[i, 'alpha3_code']='USA'
        i += 1
    elif regi == 'Republic of Korea':
        iea_clean_df.at[i, 'alpha3_code']='ROK'
        i += 1
    elif regi == 'EU27' or regi == 'Rest of the world' or regi == 'World' or regi == 'Other Europe' or regi == 'Europe':
        iea_clean_df.at[i, 'alpha3_code']=None
        i += 1
    else:
        iea_clean_df.at[i, 'alpha3_code']= str((pycountry.countries.get(name=regi).alpha_3))
        i += 1

# %%
iea_clean_df
# Out:
#      alpha3_code     region        category       parameter    mode  \
# 0            AUS  Australia      Historical        EV stock    Cars
# 1            AUS  Australia      Historical  EV sales share    Cars
# 2            AUS  Australia      Historical  EV stock share    Cars
# 3            AUS  Australia      Historical        EV sales    Cars
# 4            AUS  Australia      Historical        EV sales    Cars
# ...          ...        ...             ...             ...     ...
# 9537        None      World  Projection-APS        EV stock  Trucks
# 9538        None      World  Projection-APS        EV stock    Vans
# 9539        None      World  Projection-APS        EV stock    Vans
# 9540        None      World  Projection-APS        EV stock    Cars
# 9541        None      World  Projection-APS        EV stock    Cars
#
#      powertrain  year      unit         value
# 0           BEV  2011  Vehicles  4.900000e+01
# 1            EV  2011   percent  6.500000e-03
# 2            EV  2011   percent  4.600000e-04
# 3           BEV  2011  Vehicles  4.900000e+01
# 4           BEV  2012  Vehicles  1.700000e+02
# ...         ...   ...       ...           ...
# 9537       PHEV  2030  Vehicles  9.100000e+05
# 9538        BEV  2030  Vehicles  1.200000e+07
# 9539       PHEV  2030  Vehicles  1.300000e+06
# 9540        BEV  2030  Vehicles  1.800000e+08
# 9541       PHEV  2030  Vehicles  5.000000e+07
#
# [9542 rows x 9 columns]

# %%
iea_clean_df[iea_clean_df['region'] == 'EU27']
# Out:
#      alpha3_code region    category       parameter   mode powertrain  year  \
# 2074        None   EU27  Historical        EV stock  Buses        BEV  2010
# 2075        None   EU27  Historical        EV sales  Buses        BEV  2010
# 2076        None   EU27  Historical  EV stock share  Buses         EV  2010
# 2077        None   EU27  Historical  EV sales share   Vans         EV  2010
# 2078        None   EU27  Historical  EV stock share   Vans         EV  2010
# ...          ...    ...         ...             ...    ...        ...   ...
# 2353        None   EU27  Historical        EV stock  Buses       PHEV  2022
# 2354        None   EU27  Historical        EV stock   Vans        BEV  2022
# 2355        None   EU27  Historical        EV sales   Vans       PHEV  2022
# 2356        None   EU27  Historical        EV sales  Buses       PHEV  2022
# 2357        None   EU27  Historical        EV stock  Buses        BEV  2022
#
#           unit       value
# 2074  Vehicles     150.000
# 2075  Vehicles      27.000
# 2076   percent       0.022
# 2077   percent       0.097
# 2078   percent       0.012
# ...        ...         ...
# 2353  Vehicles     810.000
# 2354  Vehicles  210000.000
# 2355  Vehicles    2600.000
# 2356  Vehicles      69.000
# 2357  Vehicles   11000.000
#
# [284 rows x 9 columns]
